# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## Load Data

# %%
def load_tweets(tweets_attributes_file, tweets_text_file):
    df = pd.read_csv(tweets_attributes_file, index_col=0)
    text = []
    with open(tweets_text_file, 'r') as f:
        for line in f:
            text.append(line)
    df['text'] = text
    return df

# %%
tweets_attributes_file = 'sandy_tweets_attributes_rev_geocoded_formatted_timestamps.csv'
tweets_text_file = 'sandy_tweets_text_tokenized.txt'

df = load_tweets(tweets_attributes_file, tweets_text_file)
#df = pd.read_csv(open('sandy_tweets_1.csv'), encoding='utf-8', engine='c')
df.head(2)
# Out:
#              tweet_id    user_id  retweet_count           time_stamp  \
# 0  260244125050363904  295902181              0  2012-10-22 05:00:09
# 1  260244177412042752   85314436              0  2012-10-22 05:00:21
#
#    longitude   latitude           state           county  county_tweet_count  \
# 0 -74.078101  40.735218      New Jersey    Hudson County               52264
# 1 -81.505790  33.460462  South Carolina  Barnwell County                1375
#
#    sentiment                                               text
# 0          1  all i wish is to be better than yesterday and ...
# 1          0                          @imSunnyAF yesssss lawd\n

# %%
df['county'] = df['county'].replace(np.nan,'', regex=True)

# %%
# Extract hashtags and save them in a new column
#https://marcobonzanini.com/2015/03/17/mining-twitter-data-with-python-part-3-term-frequencies/
df['hashtags'] = df['text'].map(lambda x: [term for term in x.split() if term.startswith('#') and len(term)>1])
df.head(2)
# Out:
#              tweet_id    user_id  retweet_count           time_stamp  \
# 0  260244125050363904  295902181              0  2012-10-22 05:00:09
# 1  260244177412042752   85314436              0  2012-10-22 05:00:21
#
#    longitude   latitude           state           county  county_tweet_count  \
# 0 -74.078101  40.735218      New Jersey    Hudson County               52264
# 1 -81.505790  33.460462  South Carolina  Barnwell County                1375
#
#    sentiment                                               text hashtags
# 0          1  all i wish is to be better than yesterday and ...       []
# 1          0                          @imSunnyAF yesssss lawd\n       []

# %%
from collections import Counter
# Print the first 5 most frequent hashtags
hashtags = [item for sublist in df['hashtags'].tolist() for item in sublist]
hashtag_counts = Counter(hashtags)
#print (hashtag_counts.most_common(10))

df_hashtag_counts = pd.DataFrame(hashtag_counts.most_common(20), columns=['hashtags', 'count'])
df_hashtag_counts
# Out:
#              hashtags  count
# 0              #Sandy  15257
# 1              #sandy  13094
# 2               #oomf   8243
# 3     #HurricaneSandy   3973
# 4     #hurricanesandy   3710
# 5          #halloween   3670
# 6                #nyc   3368
# 7   #100ThingsAboutMe   3002
# 8          #Halloween   2842
# 9               #jobs   2565
# 10            #debate   2465
# 11     #ToMyFutureSon   2358
# 12                #NC   2217
# 13           #Clayton   2154
# 14               #NYC   2146
# 15         #hurricane   1972
# 16              #love   1919
# 17      #frankenstorm   1745
# 18           #debates   1742
# 19     #sorrynotsorry   1734

# %%
from bokeh.io import output_notebook, show
output_notebook()

from bokeh.charts import Bar, output_file#, show
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.charts.attributes import ColorAttr, CatAttr

#bar = Bar(df_monogram_tokens, 'monograms', values='count', title="test chart")
bar = Bar(df_hashtag_counts, values='count', label=CatAttr(columns=['hashtags'], sort=False),)
         # Turn off Bar Plot sorting by category axis labels
         # https://github.com/bokeh/bokeh/issues/2924
#output_file("most_common_hashtags_bokeh.html")

show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c8e4bc2-895d-4827-a86b-06cf5f7a38af">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="734a35f0-5e25-4f2c-8755-a82726edb08c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#734a35f0-5e25-4f2c-8755-a82726edb08c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("734a35f0-5e25-4f2c-8755-a82726edb08c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '734a35f0-5e25-4f2c-8755-a82726edb08c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bacbdefc-d24a-4a87-a001-0b3d4353323f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"hashtags":"#NYC"}],"color":["#f22c40"],"fill_alpha":[0.8],"hashtags":["#NYC"],"height":[2146.0],"label":[{"hashtags":"#NYC"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["#NYC"],"y":[1073.0]}},"id":"41f3ffc0-8271-418e-9c56-a0660913b8fc","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"557bcc98-b45f-4943-87b6-d509b92227f4","type":"Rect"},{"attributes":{"data_source":{"id":"2ac17b59-3c84-4e01-8dcb-a556866e9954","type":"ColumnDataSource"},"glyph":{"id":"013ade4c-3eab-4cb3-8e48-d3adaac1ec49","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cdc28665-80c4-4199-8ea0-ac5a10ccdae6","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"fb641296-8906-4afb-8c70-57b73167ae72","type":"CategoricalAxis"}],"left":[{"id":"c9482f2a-6c86-4362-a366-1925a11c33cc","type":"LinearAxis"}],"renderers":[{"id":"51bcd250-0e91-441d-a4da-2cbfbdd99c78","type":"BoxAnnotation"},{"id":"2d358779-5ba4-4f5a-afe0-751fdd4c9429","type":"GlyphRenderer"},{"id":"1ca1955d-7075-4b9c-9f84-6652234740e9","type":"GlyphRenderer"},{"id":"cdc28665-80c4-4199-8ea0-ac5a10ccdae6","type":"GlyphRenderer"},{"id":"b561175e-0cfc-4b18-a562-6e0425a30408","type":"GlyphRenderer"},{"id":"9c4de6f4-900b-4f1c-8a83-9c7b1ddbb863","type":"GlyphRenderer"},{"id":"b2581432-a636-4b65-bdf3-3b133307c43e","type":"GlyphRenderer"},{"id":"fc1d46a0-ba0e-46d4-ae2c-9fbf735dcf3f","type":"GlyphRenderer"},{"id":"c3191ab0-d743-46d3-afcd-d1dbf62afdf1","type":"GlyphRenderer"},{"id":"4cc37b6f-dc8f-4aad-8c2c-fcd61010363c","type":"GlyphRenderer"},{"id":"756126fa-16e2-4712-a84e-b302ca667f13","type":"GlyphRenderer"},{"id":"7f518ff7-c2d6-4d0e-b374-b15b11f4cadf","type":"GlyphRenderer"},{"id":"e7f2f1ed-c2f9-475d-b9cb-06a3e3ab9f83","type":"GlyphRenderer"},{"id":"a57caf8b-6774-440a-93f2-4667bb23735f","type":"GlyphRenderer"},{"id":"d054d4fa-aa7e-4e34-bf8b-1e0890cb0b65","type":"GlyphRenderer"},{"id":"fc824d54-ba8c-491b-ade1-98924fd656aa","type":"GlyphRenderer"},{"id":"7987839b-be88-4b70-9e91-47b908ce4a04","type":"GlyphRenderer"},{"id":"ea27c0ce-7dd9-4f65-864d-2400640c0793","type":"GlyphRenderer"},{"id":"4807af97-dc4f-483e-ba11-9b6cfe39577a","type":"GlyphRenderer"},{"id":"5f5a3807-10e0-4ac7-ac17-bbfc922579c5","type":"GlyphRenderer"},{"id":"85dced71-ece8-444c-8fe5-0b59785a5c4c","type":"GlyphRenderer"},{"id":"0d3a59ee-ce65-4c69-aff5-35fab9742654","type":"Legend"},{"id":"fb641296-8906-4afb-8c70-57b73167ae72","type":"CategoricalAxis"},{"id":"c9482f2a-6c86-4362-a366-1925a11c33cc","type":"LinearAxis"},{"id":"26266473-fcfd-4522-a9f3-3e23d42e2309","type":"Grid"}],"title":{"id":"f8e7a212-f28c-4649-b7ba-36dd9c88807b","type":"Title"},"tool_events":{"id":"27ca3dd4-a597-4cb0-8da5-0e583f8d8b3d","type":"ToolEvents"},"toolbar":{"id":"2a722f8d-3c33-4826-a176-15c35e2cca4d","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"371a63c9-e049-4f55-a64d-0de5c6d4aa0c","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"f682cdfa-5eab-421a-9810-b52a1e5e4f87","type":"Range1d"}},"id":"d70763d9-091c-40a1-8ff6-13759bb6786b","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2aab493c-261a-4079-9545-539ffda4403c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"widt ...

# %%
# Create a new dataframe containg tweets with only the most common hashtags
common_hashtags = df_hashtag_counts['hashtags'].tolist()

df['common_hashtag_flag'] = df['hashtags'].apply(lambda x: x!=[] and set(x).issubset(set(common_hashtags)))
df_filt = df[['time_stamp', 'hashtags']][df['common_hashtag_flag']==1]
df_filt['hashtags'] = df_filt['hashtags'].apply(tuple)
df = df.drop('common_hashtag_flag', axis=1)
print (len(df_filt))
df_filt.head()
# Out:
# 41471
#                time_stamp           hashtags
# 39    2012-10-22 05:00:03           (#oomf,)
# 696   2012-10-22 05:02:55  (#sorrynotsorry,)
# 1334  2012-10-22 05:06:05           (#oomf,)
# 1536  2012-10-22 05:07:11  (#sorrynotsorry,)
# 1909  2012-10-22 05:09:00           (#oomf,)

# %%
#https://github.com/pandas-dev/pandas/issues/10511
    
def listify(df, column):
    matches = [i for i,n in enumerate(df.columns)
               if n==column]

    if len(matches)==0:
        raise Exception('Failed to find column named ' + column +'!')
    if len(matches)>1:
        raise Exception('More than one column named ' + column +'!')

    old_index = df.index
    col_idx = matches[0] + len(old_index.shape) # Since we will reset the index

    column_names = list(df.index.names) + list(df.columns)
    gb_cols = [c for c in column_names
               if c!= column]

    # Helper function to generate the squashed dataframe
    def fnc(d):
        row = list(d.values[0])
        return pd.DataFrame([row[:col_idx]
                             + [[v[col_idx] for v in list(d.values)]]
                             + row[col_idx+1:]])

    return (df
            .reset_index()
            .groupby(gb_cols)
            .apply(fnc)
            .rename(columns = lambda i : column_names[i])
            .set_index(old_index.names)
           )

def unlistify(df, column):
    matches = [i for i,n in enumerate(df.columns)
               if n==column]

    if len(matches)==0:
        raise Exception('Failed to find column named ' + column +'!')
    if len(matches)>1:
        raise Exception('More than one column named ' + column +'!')

    col_idx = matches[0]

    # Helper function to expand and repeat the column col_idx
    def fnc(d):
        row = list(d.values[0])
        bef = row[:col_idx]
        aft = row[col_idx+1:]
        col = row[col_idx]
        z = [bef + [c] + aft for c in col]
        return pd.DataFrame(z)

    col_idx += len(df.index.shape) # Since we will push reset the index
    index_names = list(df.index.names)
    column_names = list(index_names) + list(df.columns)
    return (df
            .reset_index()
            .groupby(level=0,as_index=0)
            .apply(fnc)
            .rename(columns = lambda i :column_names[i])
            .set_index(index_names)
           )


# Examples of how to listify and unlistify a column.
#df_test = pd.DataFrame([[11,range(5),10],
#                   [22,range(3),20]],
#                   columns = ['A','B','C']).set_index('C')
#print ('org')
#print (df_test)
#print ('--')
#df_test = unlistify(df_test,'B')
#print ('unlistify(df_test,B)')
#print (df_test)
#print ('--')
#df_test = listify(df_test,'B')
#print ('listify(df_test,B)')
#print (df_test)

# %%
df_filt = unlistify(df_filt, 'hashtags')

# %%
# Extract date from datetime and save as a new column
df_filt['date'] = df_filt['time_stamp'].apply(lambda x: x.split()[0])

# %%
df_filt.groupby(['date', 'hashtags']).size()
# Out:
# date        hashtags
# 2012-10-22  #Halloween             14
#             #NC                     2
#             #NYC                   25
#             #debate                26
#             #debates               10
#             #halloween              8
#             #jobs                  69
#             #love                  25
#             #nyc                   20
#             #oomf                 348
#             #sorrynotsorry         58
# 2012-10-23  #Halloween             30
#             #NC                     4
#             #NYC                   43
#             #Sandy                  7
#             #debate              1423
#             #debates             1127
#             #halloween             24
#             #jobs                  99
#             #love                  36
#             #nyc                   29
#             #oomf                 616
#             #sorrynotsorry        105
# 2012-10-24  #Halloween             48
#             #HurricaneSandy         2
#             #NC                     2
#             #NYC                   16
#             #Sandy                 19
#             #debate                 7
#             #debates                4
#                                  ...
# 2012-11-01  #ToMyFutureSon          5
#             #debate                 1
#             #frankenstorm          11
#             #halloween            160
#             #hurricane              9
#             #hurricanesandy        65
#             #jobs                 124
#             #love                  33
#             #nyc                   50
#             #oomf                 691
#             #sandy                355
#             #sorrynotsorry        105
# 2012-11-02  #100ThingsAboutMe       5
#             #Halloween              6
#             #HurricaneSandy        21
#             #NC                     1
#             #NYC                   19
#             #Sandy                125
#             #ToMyFutureSon          4
#             #debate                 2
#             #frankenstorm           1
#             #halloween              4
#             #hurricane              3
#             #hurricanesandy        10
#             #jobs                   7
#             #love                  18
#             #nyc                    7
#             #oomf                 322
#             #sandy                 90
#             #sorrynotsorry         56
# dtype: int64

# %%
grouped_df = df_filt.groupby(['date', 'hashtags'])
df_heatmap = pd.DataFrame(grouped_df.size().reset_index(name = "Group_Count"))
df_heatmap.head()
# Out:
#          date    hashtags  Group_Count
# 0  2012-10-22  #Halloween           14
# 1  2012-10-22         #NC            2
# 2  2012-10-22        #NYC           25
# 3  2012-10-22     #debate           26
# 4  2012-10-22    #debates           10

# %%
# http://bokeh.pydata.org/en/latest/docs/gallery/heatmap_chart.html

from bokeh.io import output_notebook, show
output_notebook()
from bokeh.charts import HeatMap, bins, output_file, show
#from bokeh.layouts import column, gridplot
from bokeh.palettes import RdYlGn6, RdYlGn9
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64890dc0-5762-4298-a035-b3ba0a4e508f">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.models import ColumnDataSource, HoverTool, LinearColorMapper, LogColorMapper
from bokeh.plotting import figure
from math import pi

# %%
##http://stackoverflow.com/questions/33596491/extract-matplotlib-colormap-in-hex-format
#
#from matplotlib import cm, colors
#cmap = cm.get_cmap('Oranges', 10)    # PiYG
#
#for i in range(cmap.N):
#    rgb = cmap(i)[:3] # will return rgba, we take only first 3 so we get rgb
#    print '"%s",' % colors.rgb2hex(rgb),

# %%
output_file("sandy_hashtag_heatmap_2.html", title="Hashtags in the Sandy corpus")

# this is the colormap from the original NYTimes plot
#colors = ["#75968f", "#a5bab7", "#c9d9d3", "#e2e2e2", "#dfccce", "#ddb7b1", "#cc7878", "#933b41", "#550b1d"]
colors = ["#fff5eb", "#fee8d1", "#fdd5ac", "#fdb97d", "#fd9c51", "#f87d2a", "#e95e0d", "#ce4401", "#a23403", "#7f2704"]
mapper = LogColorMapper(palette=colors)
#mapper = LinearColorMapper(palette=colors)

df_heatmap_mat = df_heatmap.pivot(index='date', columns='hashtags', values='Group_Count')
df_heatmap_mat = df_heatmap_mat.fillna(0)

date = []
hashtag = []
color = []
count = []
for d in list(df_heatmap_mat.index):
    for h in list(df_heatmap_mat.columns):
        hashtag.append(h)
        date.append(d)
        count_hd = df_heatmap_mat[h].loc[d]
        count.append(count_hd)
        
source = ColumnDataSource(data=dict(date=date, hashtag=hashtag, count=count))

TOOLS = "hover,save,pan,box_zoom,wheel_zoom"
p = figure(#title="Hashtags",
           y_range=list(df_heatmap_mat.columns), x_range=list(df_heatmap_mat.index),
           x_axis_location="below", plot_width=900, plot_height=400,
           tools=TOOLS)

p.grid.grid_line_color = None
p.axis.axis_line_color = None
p.axis.major_tick_line_color = None
p.axis.major_label_text_font_size = "10pt"
p.axis.major_label_standoff = 0
p.xaxis.major_label_orientation = pi / 3


p.rect(y="hashtag", x="date", width=1, height=1,
       source=source,
       fill_color={'field': 'count', 'transform': mapper},
       line_color=None)

p.select_one(HoverTool).tooltips = [
    ('date', '@date'),
    ('hashtag', '@hashtag'),
    ('count', '@count'),
]

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'sandy_hashtag_heatmap_2.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="plotdiv" id="b9bd3674-dbbe-43d5-a3b1-3ec631120c64"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b9bd3674-dbbe-43d5-a3b1-3ec631120c64").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b9bd3674-dbbe-43d5-a3b1-3ec631120c64");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b9bd3674-dbbe-43d5-a3b1-3ec631120c64' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e98e08c4-e314-4841-8a52-a05e1c06e44f":{"roots":{"references":[{"attributes":{},"id":"f3d8a0d4-c160-4081-9d5c-871edf15cea1","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"}},"id":"9853d632-13b1-44cb-8a74-c2d81ff1a8b9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"}},"id":"fcf6ce45-74ca-4fb2-92bf-e80e1f8c3ad8","type":"SaveTool"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d3693d4-1484-4274-9400-397698f20a10","type":"CategoricalTicker"}},"id":"2bbed64e-c3b5-4018-a6c2-8900455aa818","type":"Grid"},{"attributes":{},"id":"9dca345d-e4d5-4bf8-aab0-76315e325113","type":"ToolEvents"},{"attributes":{"axis_line_color":{"value":null},"formatter":{"id":"f3d8a0d4-c160-4081-9d5c-871edf15cea1","type":"CategoricalTickFormatter"},"major_label_standoff":0,"major_label_text_font_size":{"value":"10pt"},"major_tick_line_color":{"value":null},"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3157e08-06a9-41fa-8111-ad3893eabd74","type":"CategoricalTicker"}},"id":"88d08566-b94c-4261-a298-cbce40f29d42","type":"CategoricalAxis"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3157e08-06a9-41fa-8111-ad3893eabd74","type":"CategoricalTicker"}},"id":"9344b112-462e-418b-8f0c-b878fc74800d","type":"Grid"},{"attributes":{},"id":"019e4762-2341-4ebc-b341-cbbd952436cc","type":"CategoricalTickFormatter"},{"attributes":{"fill_color":{"field":"count","transform":{"id":"8a905575-9656-4382-bb4d-d76a9e9ad0d1","type":"LogColorMapper"}},"height":{"units":"data","value":1},"line_color":{"value":null},"width":{"units":"data","value":1},"x":{"field":"date"},"y":{"field":"hashtag"}},"id":"3e106190-2408-46ab-86e2-b726532cb771","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9be01148-9016-4bfc-a5dc-3acf77f9d3f4","type":"HoverTool"},{"id":"fcf6ce45-74ca-4fb2-92bf-e80e1f8c3ad8","type":"SaveTool"},{"id":"4e0711e7-ec4d-4354-acc7-eccea049bd4b","type":"PanTool"},{"id":"1bca81c5-0178-4068-85d4-7fddabad29dd","type":"BoxZoomTool"},{"id":"9853d632-13b1-44cb-8a74-c2d81ff1a8b9","type":"WheelZoomTool"}]},"id":"e40e4de9-a1fe-4767-9725-d3cd4e2161cf","type":"Toolbar"},{"attributes":{"plot":null,"text":null},"id":"495fdaf7-7099-4760-8430-7167c91ba3a3","type":"Title"},{"attributes":{"axis_line_color":{"value":null},"formatter":{"id":"019e4762-2341-4ebc-b341-cbbd952436cc","type":"CategoricalTickFormatter"},"major_label_orientation":1.0471975511965976,"major_label_standoff":0,"major_label_text_font_size":{"value":"10pt"},"major_tick_line_color":{"value":null},"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d3693d4-1484-4274-9400-397698f20a10","type":"CategoricalTicker"}},"id":"2d5baa80-d218-4e61-85e2-51f399af1161","type":"CategoricalAxis"},{"attributes":{"overlay":{"id":"ab215981-8ea4-41e4-982f-521780cf2e11","type":"BoxAnnotation"},"plot":{"id":"f6cd4328-252b-43dc-b01d-816c1774d3a8","subtype":"Figure","type":"Plot"}},"id":"1bca81c5-0178-4068-85d4-7fddabad29dd","type":"BoxZoomTool"},{"attributes":{"palette":["#fff5eb","#fee8d1","#fdd5ac","#fdb97d","#fd9c51","#f87d2a","#e95e0d","#ce4401","#a23403","#7f2704"]},"id":"8a905575-9656-4382-bb4d-d76a9e9ad0d1","type":"LogColorMapper"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"date"},"y":{"field":"hashtag"}},"id":"6ada1a96-2df8-4ee2-9995-42abd27d6209","type":"Rect"},{"attributes":{},"id":"7d3693d4-1484-4274-9 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6f792bf43386> in <module>()
#      48 ]
#      49
# ---> 50 show(p)
#
# /opt/conda/lib/python2.7/site-packages/bokeh/io.pyc in show(obj, browser, new, notebook_handle)
#     312     if obj not in _state.document.roots:
#     313         _state.document.add_root(obj)
# --> 314     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     315
#     316
#
# /opt/conda/lib/python2.7/site-packages/bokeh/io.pyc in _show_with_state(obj, state, browser, new, notebook_handle)
#     330
#     331     if state.file or not shown:
# --> 332         _show_file_with_state(obj, state, new, controller)
#     333
#     334     return comms_handle
#
# /opt/conda/lib/python2.7/site-packages/bokeh/io.pyc in _show_file_with_state(obj, state, new, controller)
#     336 def _show_file_with_state(obj, state, new, controller):
#     337     filename = save(obj, state=state)
# --> 338     controller.open("file://" + filename, new=_new_param[new])
#     339
#     340 def _show_notebook_with_state(obj, state, notebook_handle):
#
# /opt/conda/lib/python2.7/webbrowser.pyc in open(url, new, autoraise)
#      59     for name in _tryorder:
#      60         browser = get(name)
# ---> 61         if browser.open(url, new, autoraise):
#      62             return True
#      63     return False
#
# /opt/conda/lib/python2.7/webbrowser.pyc in open(self, url, new, autoraise)
#     177             else:
#     178                 p = subprocess.Popen(cmdline, close_fds=True)
# --> 179             return not p.wait()
#     180         except OSError:
#     181             return False
#
# /opt/conda/lib/python2.7/subprocess.pyc in wait(self)
#    1390             while self.returncode is None:
#    1391                 try:
# -> 1392                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1393                 except OSError as e:
#    1394                     if e.errno != errno.ECHILD:
#
# /opt/conda/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     474     while True:
#     475         try:
# --> 476             return func(*args)
#     477         except (OSError, IOError) as e:
#     478             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:
