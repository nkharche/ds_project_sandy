# %%
import pandas as pd
import numpy as np
import folium
from folium import plugins
import os

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('sandy_pow_out_tweets_naive_bayes_1.csv', index_col=0)
df['county'] = df['county'].astype(str)
#print(df[df['county']=='nan'])
print (len(df))
df.head(2)
# Out:
# 7067
#                   tweet_id    user_id  retweet_count           time_stamp  \
# 24303   260455999276728320  186545667              0  2012-10-22 19:02:03
# 123333  260923579355508736  293642193              0  2012-10-24 02:00:03
#
#         longitude   latitude           state           county  \
# 24303  -72.255078  41.809409     Connecticut   Tolland County
# 123333 -80.556654  35.347399  North Carolina  Cabarrus County
#
#         county_tweet_count  sentiment  pow_outage_label
# 24303                 6983          1                 1
# 123333               15521          1                 1

# %% [markdown]
# ## Calculate total number of tweets from each county

# %%
df_all = pd.read_csv('sandy_tweets_attributes_rev_geocoded_formatted_timestamps.csv', index_col=0)
#df_all['county'] = df_all['county'].replace(np.nan,'', regex=True)
df_all['county'] = df_all['county'].astype(str)
df_all['county_tweet_count'] = df_all.groupby(['state', 'county'])['tweet_id'].transform('count')
df['county_tweet_count'] = df_all['county_tweet_count'].iloc[df.index.values]
df.head(2)
# Out:
#                   tweet_id    user_id  retweet_count           time_stamp  \
# 24303   260455999276728320  186545667              0  2012-10-22 19:02:03
# 123333  260923579355508736  293642193              0  2012-10-24 02:00:03
#
#         longitude   latitude           state           county  \
# 24303  -72.255078  41.809409     Connecticut   Tolland County
# 123333 -80.556654  35.347399  North Carolina  Cabarrus County
#
#         county_tweet_count  sentiment  pow_outage_label
# 24303                 6983          1                 1
# 123333               15521          1                 1

# %% [markdown]
# ## Power outage tweets dataframe

# %%
df['county_pow_out_count'] = df.groupby(['state', 'county'])['tweet_id'].transform('count')
df['county_pow_out_ratio'] = df['county_pow_out_count']/df['county_tweet_count']
df_pow_out_choropleth = df[['state', 'county', 'county_pow_out_ratio', 'county_tweet_count']].drop_duplicates()
df.drop(['county_pow_out_ratio'], axis=1, inplace=True)

print (max(df_pow_out_choropleth['county_pow_out_ratio']))
print (min(df_pow_out_choropleth['county_pow_out_ratio']))
df_pow_out_choropleth.head(2)
# Out:
# 0.0454545454545
# 3.42102562348e-05
#                  state           county  county_pow_out_ratio  \
# 24303      Connecticut   Tolland County              0.002291
# 123333  North Carolina  Cabarrus County              0.000193
#
#         county_tweet_count
# 24303                 6983
# 123333               15521

# %%
df_pow_out_choropleth[df_pow_out_choropleth['county']=='Rensselaer County']
# Out:
#             state             county  county_pow_out_ratio  county_tweet_count
# 3737866  New York  Rensselaer County              0.000177                5640

# %%
df_pow_out_choropleth[df_pow_out_choropleth['state']=='New York']
# Out:
#             state               county  county_pow_out_ratio  \
# 222975   New York        Nassau County              0.005619
# 356713   New York      Dutchess County              0.001593
# 407706   New York        Queens County              0.003485
# 414202   New York   Schenectady County              0.000619
# 416422   New York       Suffolk County              0.004370
# 481751   New York         Kings County              0.001843
# 504551   New York      New York County              0.002144
# 511060   New York      Onondaga County              0.000230
# 512883   New York        Monroe County              0.000361
# 519427   New York   Westchester County              0.004891
# 522543   New York       Ontario County              0.000578
# 526192   New York                  nan              0.004476
# 528121   New York      Rockland County              0.010238
# 528609   New York        Orange County              0.003114
# 540577   New York        Ulster County              0.001529
# 544912   New York   Cattaraugus County              0.000405
# 553167   New York        Putnam County              0.005577
# 553705   New York      Richmond County              0.005552
# 560119   New York     Schoharie County              0.002937
# 562729   New York          Erie County              0.000218
# 579682   New York      Sullivan County              0.003766
# 580038   New York      Cortland County              0.000896
# 657475   New York                Bronx              0.001827
# 709192   New York        Albany County              0.000169
# 732155   New York        Broome County              0.000192
# 759530   New York        Otsego County              0.001116
# 774530   New York      Delaware County              0.002587
# 1318251  New York  St. Lawrence County              0.000852
# 1330077  New York      Herkimer County              0.001374
# 1333127  New York         Wayne County              0.000762
# 1442799  New York       Niagara County              0.000133
# 2027164  New York        Oneida County              0.000449
# 2098110  New York      Tompkins County              0.000824
# 2101304  New York    Montgomery County              0.000685
# 2119090  New York        Oswego County              0.000258
# 2131320  New York    Chautauqua County              0.000147
# 2165188  New York        Warren County              0.000612
# 2183222  New York       Madison County              0.000543
# 2905914  New York        Seneca County              0.001572
# 2910744  New York      Saratoga County              0.000768
# 2950999  New York       Chemung County              0.000149
# 3737866  New York    Rensselaer County              0.000177
#
#          county_tweet_count
# 222975                45917
# 356713                13185
# 407706                58831
# 414202                 4844
# 416422                54009
# 481751                46132
# 504551                68107
# 511060                21755
# 512883                35964
# 519427                31486
# 522543                 5186
# 526192                51833
# 528121                 6349
# 528609                16379
# 540577                 5232
# 544912                 2467
# 553167                 3945
# 553705                14049
# 560119                  681
# 562729                59531
# 579682                 1593
# 580038                 2233
# 657475                18612
# 709192                17708
# 732155                 5203
# 759530                 3585
# 774530                  773
# 1318251                2348
# 1330077                2184
# 1333127                2625
# 1442799                7536
# 2027164                8902
# 2098110                3642
# 2101304                1459
# 2119090                3872
# 2131320                6797
# 2165188                1633
# 2183222                1841
# 2905914                 636
# 2910744                5205
# 2950999                6704
# 3737866                5640

# %% [markdown]
# ## Geospatial map

# %% [markdown]
# ### Normalize tweet counts by total number tweets from that each county

# %%
weights = 1.0/df['county_tweet_count'].values
weights = weights/max(weights)
weights
# Out:
# array([ 0.00315051,  0.00141743,  0.00047913, ...,  0.00315051,
#         0.00055319,  0.00042609])

# %%
lats = df['latitude'].values
lons = df['longitude'].values
#np.mean(lats), np.mean(lons)

m = folium.Map(location=[np.mean(lats), np.mean(lons)], zoom_start=5)
m.add_children(plugins.HeatMap(zip(lats, lons, 100000*weights), radius = 6))
m.save(os.path.join('results', 'power_outage_map_folium.html'))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
df_us_counties = pd.read_csv('national_county.txt', names=['STATE', 'STATEFP', 'COUNTYFP', 'COUNTYNAME', 'CLASSFP'], 
                             dtype={'STATEFP': object, 'COUNTYFP': object})
df_us_counties['FIPS'] = df_us_counties[['STATEFP', 'COUNTYFP']].apply(lambda x: x[0]+x[1], axis=1)
df_us_counties.head()
# Out:
#   STATE STATEFP COUNTYFP      COUNTYNAME CLASSFP   FIPS
# 0    AL      01      001  Autauga County      H1  01001
# 1    AL      01      003  Baldwin County      H1  01003
# 2    AL      01      005  Barbour County      H1  01005
# 3    AL      01      007     Bibb County      H1  01007
# 4    AL      01      009   Blount County      H1  01009

# %%
states_abbr = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}
#states_abbr = pd.DataFrame(states_abbr.items(), columns=['Abbreviation', 'State'])
#states_abbr.head(2)
states_abbr = dict((v,k) for k,v in states_abbr.iteritems())

# %%
df_us_counties.head(2)
# Out:
#   STATE STATEFP COUNTYFP      COUNTYNAME CLASSFP   FIPS
# 0    AL      01      001  Autauga County      H1  01001
# 1    AL      01      003  Baldwin County      H1  01003

# %%
df_us_counties[(df_us_counties['STATE']=='NY') & (df_us_counties['COUNTYNAME']=='Rensselaer County')]['FIPS']
#df_pow_out_choropleth[df_pow_out_choropleth['state']=='New York']
# Out:
# 1869    36083
# Name: FIPS, dtype: object

# %%
df_pow_out_choropleth[(df_pow_out_choropleth['state']=='New York') & (df_pow_out_choropleth['county']=='Bronx')]
# Out:
#            state county  county_pow_out_ratio  county_tweet_count
# 657475  New York  Bronx              0.001827               18612

# %%
df_us_counties[(df_us_counties['STATE']=='NY') & (df_us_counties['COUNTYNAME']=='Bronx County')]#['FIPS'].values[0]
# Out:
#      STATE STATEFP COUNTYFP    COUNTYNAME CLASSFP   FIPS
# 1830    NY      36      005  Bronx County      H6  36005

# %%
def get_state_county_fips(state, county):
    #print (state, county)
    if state=='Washington, D.C.':
        fips = '11001'
        return fips    
    if state == 'New York' and county=='nan':
        county = 'New York County'        
    if state == 'New York' and county=='Bronx':
        county = 'Bronx County'        
    if 'City of ' in county:
        county = county.replace('City of ', '')
        county += ' city'
    if 'Saint ' in county:
        county = county.replace('Saint ', 'St. ')
    fips = df_us_counties[(df_us_counties['STATE']==states_abbr[state]) & (df_us_counties['COUNTYNAME']==county)]['FIPS'].values[0]
    return fips

df_pow_out_choropleth['fips'] = df_pow_out_choropleth[['state', 'county']].apply(lambda x: get_state_county_fips(x[0], x[1]), axis=1)    

#df_pow_out_choropleth[(df_pow_out_choropleth['state']=='New York') & (df_pow_out_choropleth['county']=='Rensselaer County')]

# %%
#df_pow_out_choropleth.to_csv('df_pow_out_choropleth.csv', index=False)
#df_pow_out_choropleth.head()

# %%
df_pow_out_choropleth[(df_pow_out_choropleth['state']=='New York') & (df_pow_out_choropleth['county']=='Rensselaer County')]
# Out:
#             state             county  county_pow_out_ratio  \
# 3737866  New York  Rensselaer County              0.000177
#
#          county_tweet_count   fips
# 3737866                5640  36083

# %%
df_zcta_county_rel_10 = pd.read_csv('zcta_county_rel_10.txt', usecols=['ZCTA5', 'STATE', 'COUNTY', 'GEOID'], 
                                    dtype={'ZCTA5':str, 'STATE':str, 'COUNTY':str, 'GEOID':str})

df_zcta_county_rel_10.head()
# Out:
#    ZCTA5 STATE COUNTY  GEOID
# 0  00601    72    001  72001
# 1  00601    72    141  72141
# 2  00602    72    003  72003
# 3  00603    72    005  72005
# 4  00606    72    093  72093

# %%
df_us_counties = pd.read_csv('national_county.txt', names=['STATE', 'STATEFP', 'COUNTYFP', 'COUNTYNAME', 'CLASSFP'], 
                             dtype={'STATEFP': object, 'COUNTYFP': object})
df_us_counties['FIPS'] = df_us_counties[['STATEFP', 'COUNTYFP']].apply(lambda x: x[0]+x[1], axis=1)
df_us_counties.head()
# Out:
#   STATE STATEFP COUNTYFP      COUNTYNAME CLASSFP   FIPS
# 0    AL      01      001  Autauga County      H1  01001
# 1    AL      01      003  Baldwin County      H1  01003
# 2    AL      01      005  Barbour County      H1  01005
# 3    AL      01      007     Bibb County      H1  01007
# 4    AL      01      009   Blount County      H1  01009

# %%
df_test = pd.merge(df_zcta_county_rel_10, df_us_counties, left_on='GEOID', right_on='FIPS', how='inner')
df_test = df_test.drop(['STATE_x', 'COUNTY', 'GEOID', 'STATE_y', 'STATEFP', 'COUNTYFP', 'COUNTYNAME', 'CLASSFP'], 1)
df_zcta_county_rel_10 = df_test
df_zcta_county_rel_10[df_zcta_county_rel_10['FIPS']=='36083']
# Out:
#       ZCTA5   FIPS
# 3611  12018  36083
# 3612  12022  36083
# 3613  12028  36083
# 3614  12033  36083
# 3615  12040  36083
# 3616  12052  36083
# 3617  12057  36083
# 3618  12061  36083
# 3619  12062  36083
# 3620  12063  36083
# 3621  12089  36083
# 3622  12090  36083
# 3623  12094  36083
# 3624  12118  36083
# 3625  12121  36083
# 3626  12123  36083
# 3627  12138  36083
# 3628  12140  36083
# 3629  12144  36083
# 3630  12153  36083
# 3631  12154  36083
# 3632  12156  36083
# 3633  12168  36083
# 3634  12169  36083
# 3635  12180  36083
# 3636  12182  36083
# 3637  12184  36083
# 3638  12185  36083
# 3639  12196  36083
# 3640  12198  36083

# %%
df_pow_out_choropleth[df_pow_out_choropleth['county']=='Rensselaer County']
# Out:
#             state             county  county_pow_out_ratio  \
# 3737866  New York  Rensselaer County              0.000177
#
#          county_tweet_count   fips
# 3737866                5640  36083

# %%
df_pow_out_zcta_choropleth = pd.merge(df_pow_out_choropleth, df_zcta_county_rel_10, left_on='fips', right_on='FIPS')
df_pow_out_zcta_choropleth = df_pow_out_zcta_choropleth.drop('fips', 1)

df_pow_out_zcta_choropleth[(df_pow_out_zcta_choropleth['state']=='New York') & (df_pow_out_zcta_choropleth['county']=='Rensselaer County')]
# Out:
#          state             county  county_pow_out_ratio  county_tweet_count  \
# 7831  New York  Rensselaer County              0.000177                5640
# 7832  New York  Rensselaer County              0.000177                5640
# 7833  New York  Rensselaer County              0.000177                5640
# 7834  New York  Rensselaer County              0.000177                5640
# 7835  New York  Rensselaer County              0.000177                5640
# 7836  New York  Rensselaer County              0.000177                5640
# 7837  New York  Rensselaer County              0.000177                5640
# 7838  New York  Rensselaer County              0.000177                5640
# 7839  New York  Rensselaer County              0.000177                5640
# 7840  New York  Rensselaer County              0.000177                5640
# 7841  New York  Rensselaer County              0.000177                5640
# 7842  New York  Rensselaer County              0.000177                5640
# 7843  New York  Rensselaer County              0.000177                5640
# 7844  New York  Rensselaer County              0.000177                5640
# 7845  New York  Rensselaer County              0.000177                5640
# 7846  New York  Rensselaer County              0.000177                5640
# 7847  New York  Rensselaer County              0.000177                5640
# 7848  New York  Rensselaer County              0.000177                5640
# 7849  New York  Rensselaer County              0.000177                5640
# 7850  New York  Rensselaer County              0.000177                5640
# 7851  New York  Rensselaer County              0.000177                5640
# 7852  New York  Rensselaer County              0.000177                5640
# 7853  New York  Rensselaer County              0.000177                5640
# 7854  New York  Rensselaer County              0.000177                5640
# 7855  New York  Rensselaer County              0.000177                5640
# 7856  New York  Rensselaer County              0.000177                5640
# 7857  New York  Rensselaer County              0.000177                5640
# 7858  New York  Rensselaer County              0.000177                5640
# 7859  New York  Rensselaer County              0.000177                5640
# 7860  New York  Rensselaer County              0.000177                5640
#
#       ZCTA5   FIPS
# 7831  12018  36083
# 7832  12022  36083
# 7833  12028  36083
# 7834  12033  36083
# 7835  12040  36083
# 7836  12052  36083
# 7837  12057  36083
# 7838  12061  36083
# 7839  12062  36083
# 7840  12063  36083
# 7841  12089  36083
# 7842  12090  36083
# 7843  12094  36083
# 7844  12118  36083
# 7845  12121  36083
# 7846  12123  36083
# 7847  12138  36083
# 7848  12140  36083
# 7849  12144  36083
# 7850  12153  36083
# 7851  12154  36083
# 7852  12156  36083
# 7853  12168  36083
# 7854  12169  36083
# 7855  12180  36083
# 7856  12182  36083
# 7857  12184  36083
# 7858  12185  36083
# 7859  12196  36083
# 7860  12198  36083

# %%
a = min(df_pow_out_zcta_choropleth['county_pow_out_ratio'])
b = max(df_pow_out_zcta_choropleth['county_pow_out_ratio'])

# %%
df_pow_out_zcta_choropleth[df_pow_out_zcta_choropleth['county_pow_out_ratio']==b]
# Out:
#               state            county  county_pow_out_ratio  \
# 3475  West Virginia  Doddridge County              0.045455
# 3476  West Virginia  Doddridge County              0.045455
# 3477  West Virginia  Doddridge County              0.045455
# 3478  West Virginia  Doddridge County              0.045455
# 3479  West Virginia  Doddridge County              0.045455
# 3480  West Virginia  Doddridge County              0.045455
# 3481  West Virginia  Doddridge County              0.045455
# 3482  West Virginia  Doddridge County              0.045455
#
#       county_tweet_count  ZCTA5   FIPS
# 3475                  22  26339  54017
# 3476                  22  26411  54017
# 3477                  22  26415  54017
# 3478                  22  26426  54017
# 3479                  22  26436  54017
# 3480                  22  26443  54017
# 3481                  22  26448  54017
# 3482                  22  26456  54017

# %%
max(df_pow_out_zcta_choropleth['county_tweet_count'])
# Out:
# 87991

# %%
len(df_pow_out_zcta_choropleth['county_tweet_count'][df_pow_out_zcta_choropleth['county_tweet_count']<1000])
# Out:
# 660

# %%
df_pow_out_zcta_choropleth = df_pow_out_zcta_choropleth[df_pow_out_zcta_choropleth['county_tweet_count'] > 1000]

# %%
df_pow_out_zcta_choropleth = df_pow_out_zcta_choropleth[df_pow_out_zcta_choropleth['county_pow_out_ratio'] > 0.0005]

# %%
len(df_pow_out_zcta_choropleth)
# Out:
# 4960

# %%
df_pow_out_zcta_choropleth.to_csv('df_pow_out_zcta_choropleth.csv', index=False)
df_pow_out_zcta_choropleth.head()
# Out:
#          state          county  county_pow_out_ratio  county_tweet_count  \
# 0  Connecticut  Tolland County              0.002291                6983
# 1  Connecticut  Tolland County              0.002291                6983
# 2  Connecticut  Tolland County              0.002291                6983
# 3  Connecticut  Tolland County              0.002291                6983
# 4  Connecticut  Tolland County              0.002291                6983
#
#    ZCTA5   FIPS
# 0  06029  09013
# 1  06043  09013
# 2  06066  09013
# 3  06071  09013
# 4  06076  09013

# %%
a = min(df_pow_out_zcta_choropleth['county_pow_out_ratio'])
b = max(df_pow_out_zcta_choropleth['county_pow_out_ratio'])
for i in xrange(5):
    print (a + (b-a)*i/5)
# Out:
# 0.000516440006886
# 0.00247197553492
# 0.00442751106296
# 0.00638304659099
# 0.00833858211902

# %% [markdown]
# ### CartoDB geocode
# UPDATE df_pow_out_zipcode_choropleth set description = '0'||zip where char_length(zip) = 4
#
# Import ZCTA as string. First row 06076 --> "06076". Delete quotes manually.
#
# UPDATE df_pow_out_zcta_choropleth SET the_geom = cdb_geocode_postalcode_polygon(ZCTA5, 'USA')

# %%
import folium
import json

county_geo = r'us-counties.json'

map1 = folium.Map(location=[39.8282, -98.5795], zoom_start=4)
map1.geo_json(county_geo, data=df_pow_out_choropleth,
             columns=['FIPS_Code', 'county_pow_out_ratio'], key_on='feature.id',
             fill_color='YlGnBu', line_opacity=0.3)#,
             #quantize_range=[0, 5000])
map1
